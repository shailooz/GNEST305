# %%
import zipfile
with zipfile.ZipFile("data.zip", 'r') as zip_ref:
    zip_ref.extractall("")

# %% [markdown]
# ## Read an image

# %%
import numpy as np
import cv2
img = cv2.imread('data/car.jpg')

# %% [markdown]
# ## Display an image

# %%
from google.colab.patches import cv2_imshow

#cv2.imshow('image',img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

cv2_imshow(img)

# %% [markdown]
# ## Write an image

# %%
cv2.imwrite('data/car.png',img)

# %% [markdown]
# ## Using Matplotlib

# %%
import cv2
from matplotlib import pyplot as plt
img = cv2.imread('data/car.jpg')
plt.imshow(img)
plt.show()

# %% [markdown]
# ## Crop a part of the image

# %%
from PIL import Image

im = Image.open('data/car.jpg')
im_crop = im.crop((280, 280, 1500, 1200))
im_crop.save('data/cropedImage.jpg', quality=95)
plt.imshow(im_crop)
plt.show()

# %% [markdown]
# ## Crop the center of the image

# %%
from PIL import Image
im = Image.open('data/car.jpg')
img_width, img_height = im.size
imgCrp=im.crop(((img_width) // 4,
                         (img_height) // 4,
                         (img_width) // 2,
                         (img_height) // 2))
plt.imshow(imgCrp)
plt.show()

# %% [markdown]
# ## Rotate an Image

# %%
import cv2
img=cv2.imread("data/car.jpg")
h,w=img.shape[0:2]
rotationMatrix=cv2.getRotationMatrix2D((w/2,h/2),90,.5)
rotateImage=cv2.warpAffine(img,rotationMatrix,(w,h))
plt.imshow(rotateImage)
plt.show()

# %% [markdown]
# ## Resize an Image

# %%
import cv2
img=cv2.imread("data/car.jpg")
newImg=cv2.resize(img,(0,0),fy=0.25,fx=0.3)
plt.imshow(newImg)
plt.show()

# %%
newImg2=cv2.resize(img,(800,600))
plt.imshow(newImg2)
plt.show()

# %% [markdown]
# ## Draw a text string on any image

# %%
import cv2
image=cv2.imread("data/car.jpg")
# Window name in which image is displayed
window_name = 'Image'
image=cv2.resize(image,(800,600))
# font
font = cv2.FONT_HERSHEY_SIMPLEX

# org
org = (50, 50)

# fontScale
fontScale = 1

# Blue color in BGR
color = (255, 0, 0)

# Line thickness of 2 px
thickness = 2

# Using cv2.putText() method
image = cv2.putText(image, 'sample text on image', org, font, fontScale, color, thickness, cv2.LINE_AA)

# Displaying the image
plt.imshow(image)
plt.show()

# %% [markdown]
# ## **COLOR SPACES**
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **LAB**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **YCrCb**
#
# ![image.png](data:image/png;base64,...)

# %%
# prompt: Load the image apple.png and convert it into gray, hsv, lab, ycrcb the plot all of them including rgb as subplots in a row

import zipfile
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
from PIL import Image

# Load the image
image = cv2.imread('data/Apple.png')

# Convert to grayscale
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Convert to HSV
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# Convert to LAB
lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)

# Convert to YCrCb
ycrcb = cv2.cvtColor(image, cv2.COLOR_BGR2YCrCb)


# Create subplots
fig, axes = plt.subplots(1, 5, figsize=(20, 5))

# Plot RGB
axes[0].imshow(rgb)
axes[0].set_title('RGB')
axes[0].axis('off')

# Plot grayscale
axes[1].imshow(gray, cmap='gray')
axes[1].set_title('Gray')
axes[1].axis('off')

# Plot HSV
axes[2].imshow(hsv)
axes[2].set_title('HSV')
axes[2].axis('off')


# Plot LAB
axes[3].imshow(lab)
axes[3].set_title('LAB')
axes[3].axis('off')

# Plot YCrCb
axes[4].imshow(ycrcb)
axes[4].set_title('YCrCb')
axes[4].axis('off')


plt.show()

# %%
import cv2
from matplotlib import pyplot as plt
from PIL import Image

# Load the image
image = cv2.imread('data/flower.jpg')

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply histogram equalization
equalized_gray = cv2.equalizeHist(gray)

# Display the original and equalized grayscale images
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

axes[0].imshow(gray, cmap='gray')
axes[0].set_title('Original Grayscale')
axes[0].axis('off')

axes[1].imshow(equalized_gray, cmap='gray')
axes[1].set_title('Equalized Grayscale')
axes[1].axis('off')

plt.show()

# %%
# prompt: plot both histograms as two histplot

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'gray' and 'equalized_gray' are already defined from the previous code

# Flatten the images into 1D arrays
gray_flat = gray.flatten()
equalized_gray_flat = equalized_gray.flatten()

# Create the subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plot the histograms
sns.histplot(gray_flat, kde=False, ax=axes[0])
axes[0].set_title('Original Grayscale Histogram')
axes[0].set_xlabel('Pixel Intensity')
axes[0].set_ylabel('Frequency')


sns.histplot(equalized_gray_flat, kde=False, ax=axes[1])
axes[1].set_title('Equalized Grayscale Histogram')
axes[1].set_xlabel('Pixel Intensity')
axes[1].set_ylabel('Frequency')


plt.tight_layout() # Adjust layout to prevent overlapping
plt.show()

# %% [markdown]
# # Morphological Transformations

# %% [markdown]
# ### 1. Erosion

# %%
import cv2
import numpy as np
img = cv2.imread('data/sample.jpg',0)
img=256-img
plt.imshow( img)
plt.show()

# %%
kernel = np.ones((5,5),np.uint8)
erosion = cv2.erode(img,kernel,iterations = 1)
plt.imshow(erosion)
plt.show()

# %% [markdown]
# ### 2. Dilation

# %%
import cv2
import numpy as np
img = cv2.imread('data/sample.jpg',0)
img=256-img
plt.imshow( img)
plt.show()
kernel = np.ones((5,5),np.uint8)
dilation = cv2.dilate(img,kernel,iterations = 1)
plt.imshow( dilation)
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image in grayscale
img = cv2.imread('data/flower.jpg', 0)

# Various Thresholding techniques
ret, thresh1 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(img, 127, 255, cv2.THRESH_TRUNC)
ret, thresh4 = cv2.threshold(img, 127, 255, cv2.THRESH_TOZERO)
ret, thresh5 = cv2.threshold(img, 127, 255, cv2.THRESH_TOZERO_INV)

titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]

# Display the images
for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# %%
import cv2
from matplotlib import pyplot as plt

# Load the image in grayscale
img = cv2.imread('data/flower.jpg', 0)

# Apply different edge detection techniques
laplacian = cv2.Laplacian(img, cv2.CV_64F)
sobelx = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=5)
sobely = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=5)
edges = cv2.Canny(img, 100, 200)  # Adjust thresholds as needed

# Display the results
plt.figure(figsize=(15, 5))

plt.subplot(1, 5, 1), plt.imshow(img, cmap='gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])

plt.subplot(1, 5, 2), plt.imshow(laplacian, cmap='gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])

plt.subplot(1, 5, 3), plt.imshow(sobelx, cmap='gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])

plt.subplot(1, 5, 4), plt.imshow(sobely, cmap='gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

plt.subplot(1, 5, 5), plt.imshow(edges, cmap='gray')
plt.title('Canny'), plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# # Image Feature Extraction

# %% [markdown]
# Represent an image as a vector of real values

# %% [markdown]
# ## Pixel values itself as an image descriptor

# %%
img = cv2.imread("./data/flower.jpg",0)
features = img.ravel()
print(features)

# %% [markdown]
# ## Histogram as image descriptor

# %%
img = cv2.imread("./data/flower.jpg",0)
hist = cv2.calcHist([img], [0], None, [256], [0, 256])

# Print the histogram values
print(hist.ravel())

# %% [markdown]
# ## Mean of RGB values as a color descriptor

# %%
img1 = cv2.imread("./data/Apple.png")
img1 = cv2.cvtColor( img1,cv2.COLOR_BGR2RGB)
channels = cv2.mean(img1)
features = np.array((channels[0], channels[1], channels[2]))
print(features)

img2 = cv2.imread("./data/strawberry.jpg")
img2 = cv2.cvtColor( img2,cv2.COLOR_BGR2RGB)
channels = cv2.mean(img2)
features = np.array((channels[0], channels[1], channels[2]))
print(features)
img3 = cv2.imread("./data/grapes.jpg")
img3 = cv2.cvtColor( img3,cv2.COLOR_BGR2RGB)
channels = cv2.mean(img3)
features = np.array((channels[0], channels[1], channels[2]))
print(features)
plt.subplot(131), plt.imshow(img1)
plt.subplot(132), plt.imshow(img2)
plt.subplot(133), plt.imshow(img3)

# %% [markdown]
# ## Intensity invariant feature descriptors

# %%
img1 = cv2.imread("./data/intens1.png")
img2 = cv2.imread("./data/intens2.png")
plt.subplot(121), plt.imshow(img1)
plt.subplot(122), plt.imshow(img2)

# %%
img_1_rgb = cv2.cvtColor( img1,cv2.COLOR_BGR2RGB)
channels = cv2.mean(img_1_rgb)
features = np.array((channels[0], channels[1], channels[2]))
print(features)

img_2_rgb = cv2.cvtColor( img2,cv2.COLOR_BGR2RGB)
channels = cv2.mean(img_2_rgb)
features = np.array((channels[0], channels[1], channels[2]))
print(features)

# %%
img_1_lab = cv2.cvtColor( img1,cv2.COLOR_BGR2LAB)
channels = cv2.mean(img_1_lab)
features = np.array((channels[0], channels[1], channels[2]))
print(features)

img_2_lab = cv2.cvtColor( img2,cv2.COLOR_BGR2LAB)
channels = cv2.mean(img_2_lab)
features = np.array((channels[0], channels[1], channels[2]))
print(features)

# %% [markdown]
# # Shape Based Feature Descriptors

# %%
img1 = cv2.imread("./data/brain1.jpg",cv2.IMREAD_COLOR)
img2 = cv2.imread("./data/brain2.jpg",cv2.IMREAD_COLOR)

img1 = cv2.resize(img1,(150,150))
img2 = cv2.resize(img2,(150,150))

plt.subplot(121), plt.imshow(img1)
plt.subplot(122), plt.imshow(img2)
plt.show()

# %%
img1_gray = cv2.cvtColor( img1,cv2.COLOR_BGR2GRAY)
img2_gray = cv2.cvtColor( img2,cv2.COLOR_BGR2GRAY)


ret,t_img1 = cv2.threshold(img1_gray,160,255,cv2.THRESH_BINARY)
ret,t_img2 = cv2.threshold(img2_gray,160,255,cv2.THRESH_BINARY)

plt.subplot(121), plt.imshow(t_img1)
plt.subplot(122), plt.imshow(t_img2)
plt.show()

# %%
kernel = np.ones((5,5),np.uint8)
t_img1 = cv2.morphologyEx(t_img1, cv2.MORPH_OPEN, kernel)
t_img2 = cv2.morphologyEx(t_img2, cv2.MORPH_OPEN, kernel)

plt.subplot(121), plt.imshow(t_img1)
plt.subplot(122), plt.imshow(t_img2)
plt.show()

# %%
f1=[]
f2=[]

contours1,hierarchy = cv2.findContours(t_img1, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
cnt1 = contours1[0]
contours2,hierarchy = cv2.findContours(t_img2, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
cnt2 = contours2[0]

area1 = cv2.contourArea(cnt1)
print(area1)
f1.append(area1)

area2 = cv2.contourArea(cnt2)
print(area2)
f2.append(area2)

perimeter1 = cv2.arcLength(cnt1,True)
print(perimeter1)
f1.append(perimeter1)

perimeter2 = cv2.arcLength(cnt2,True)
print(perimeter2)
f2.append(perimeter2)

# %%
img1 = cv2.imread("./data/brain1.jpg",cv2.IMREAD_COLOR)
img2 = cv2.imread("./data/brain2.jpg",cv2.IMREAD_COLOR)

img1 = cv2.resize(img1,(150,150))
img2 = cv2.resize(img2,(150,150))

x,y,w,h = cv2.boundingRect(cnt1)
print(w,h)
f1.extend([w,h])
rimg_1 = cv2.rectangle(img1,(x,y),(x+w,y+h),(0,255,0),2)

x,y,w,h = cv2.boundingRect(cnt2)
print(w,h)
f2.extend([w,h])
rimg_2 = cv2.rectangle(img2,(x,y),(x+w,y+h),(0,255,0),2)

plt.subplot(121), plt.imshow(rimg_1)
plt.subplot(122), plt.imshow(rimg_2)
plt.show()

# %%
img1 = cv2.imread("./data/brain1.jpg",cv2.IMREAD_COLOR)
img2 = cv2.imread("./data/brain2.jpg",cv2.IMREAD_COLOR)

img1 = cv2.resize(img1,(150,150))
img2 = cv2.resize(img2,(150,150))
(x,y),radius = cv2.minEnclosingCircle(cnt1)
center = (int(x),int(y))
radius = int(radius)
print(x,y,radius)
f1.append(radius)
cimg_1 = cv2.circle(img1,center,radius,(255,0,0),2)


(x,y),radius = cv2.minEnclosingCircle(cnt2)
center = (int(x),int(y))
radius = int(radius)
print(x,y,radius)
f2.append(radius)
cimg_2 = cv2.circle(img2,center,radius,(255,0,0),2)
plt.subplot(121), plt.imshow(cimg_1)
plt.subplot(122), plt.imshow(cimg_2)
plt.show()

# %%
print(f1)
print(f2)

# %%
moments = cv2.moments(t_img1)
huMoments = cv2.HuMoments(moments)
print(huMoments.ravel())

# %%
moments = cv2.moments(t_img2)
huMoments = cv2.HuMoments(moments)
print(huMoments.ravel())

# %% [markdown]
# ---
#
# ![hu.png](data:image/png;base64,...)
